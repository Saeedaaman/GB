# %% [markdown]
# <a href="https://colab.research.google.com/github/Saeedaaman/GB/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
image_file_path = '/content/drive/MyDrive/DS/data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/DS/data'
# Out:
# image  label

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPool2D
from keras.models import Model,Sequential
import numpy as np
from keras. preprocessing.image import ImageDataGenerator
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile
import os

# %%
zipfile = 'content/drive/MyDrive/DS/data'
unzipdirectory='/content/drive/MyDrive/DS'

# %%
# !ls
!7za -y e "/content/drive/MyDrive/DS/data/image/origin.7z.*" -o"/content/drive/MyDrive/DS/processed_data"
# Out:
# drive  gdrive  sample_data
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 8 files, 8113576419 bytes (7738 MiB)
#   0%
# Extracting archive: /content/drive/MyDrive/DS/data/image/origin.7z.001
# --
# Path = /content/drive/MyDrive/DS/data/image/origin.7z.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 8
# Total Physical Size = 8113576419
# ----
# Path = origin.7z
# Size = 8113576419
# --
# Path = origin.7z
# Type = 7z
# Physical Size = 8113576419
# Headers Size = 863607
# Method = LZMA:25
# Solid = +
# Blocks = 2
#
#   6% 5984 - origin/amazed_father_284.jpg
