# %% [markdown]
# <a href="https://colab.research.google.com/github/Saeedaaman/GB/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyMuPDF
import fitz  # PyMuPDF
import os
# List of PDF file paths
pdf_files = ['/content/A.pdf', '/content/B.pdf', '/content/C.pdf', '/content/Ch.pdf', '/content/C̃h.pdf', '/content/Dh.pdf', '/content/D̃.pdf', '/content/E.pdf', '/content/F.pdf', '/content/G.pdf', '/content/Gh.pdf', '/content/G̃h.pdf', '/content/H.pdf', '/content/I.pdf', '/content/J.pdf', '/content/K.pdf', '/content/Kh.pdf', '/content/K̃h.pdf', '/content/L.pdf', '/content/N.pdf', '/content/O.pdf', '/content/P.pdf', '/content/Q.pdf', '/content/R.pdf', '/content/S.pdf', '/content/Sh.pdf', '/content/S̃h.pdf', '/content/T.pdf', '/content/Th.pdf', '/content/T̃.pdf', '/content/U.pdf', '/content/V.pdf', '/content/W.pdf', '/content/Y.pdf', '/content/Z.pdf', '/content/Zh.pdf', '/content/Z̃.pdf', '/content/Z̃h.pdf', '/content/Ũ.pdf']  # Add more file paths as needed

for pdf_path in pdf_files:
    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Extract text from each page
    pdf_text = ""
    for page_number in range(len(pdf_document)):
        page = pdf_document[page_number]
        pdf_text += page.get_text()

    # Close the PDF after extraction
    pdf_document.close()

    # Output a snippet of the text
    print(f"Text from {pdf_path}:\n{pdf_text}")
# Out:
# Streaming output truncated to the last 5000 lines.
# k̃hũ dẽstan
#
# for self
# K̃hũn
#
#
# own
# K̃hũy
#
#
# sister
# K̃hũynan nẽpus
#
# granddaughter
#
# Text from /content/L.pdf:
# L
# Lakhsẽn
#
#
# lambing
# Lalẽm
#
#
# uncontrolled, unrestrained, wild, poor
# Laq
#
#
# without cloth
# Laqwa
#
#
#  stroke, brain attack
# Law palaw
#
# polishing, makeup
# law palaw
#
#
# political
# Lecẽr
#
#
# leave, ignore, disregard, neglect, allow, release
# Leng
#
#
# leg
# Lep
#
#
# mud for repairing or construction buildings
# Lew
#
#
# mad, senseless, pointless, angry
# Ley
#
#
#
# la (a musical note)
# Letifa
#
#
# joke
# Lẽman din
#
# fighting, quarrel, argument
# Lẽman khor
#
# warlike, bellicose, belligerent, abrasive, harsh
# Lẽnz̃ek
#
#
# jogging
# Lẽqa
#
#
# clip
# Lẽqum
#
#
# throat
# Lẽrza k̃hak
#
# trembling, vibrating, quivering, quaking, shaking, shuddering
# Lẽtifayisht
#
# Jokes
# Lẽvonj
#
#
# underwater slippery mud on stones
# Lẽz̃ek
#
#
# jogging
# Lic̃h
# ...
